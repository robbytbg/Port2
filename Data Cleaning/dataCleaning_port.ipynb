# %% [markdown]
# <a href="https://colab.research.google.com/github/robbytbg/Port2/blob/main/dataCleaning_port.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data=pd.read_csv('/content/fifa21 raw data v2.csv')
# Out:
# <ipython-input-458-c23dc278615b>:3: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('/content/fifa21 raw data v2.csv')

# %%
data.head(5)
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
data.drop(data.columns[[3,4,18]],axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                0
# Name              0
# LongName          0
# Nationality       0
# Age               0
#                ...
# PAS               0
# DRI               0
# DEF               0
# PHY               0
# Hits           2595
# Length: 74, dtype: int64

# %%
data['Hits'].fillna(0, inplace=True)

# %%
data=data.rename(columns={'LongName':'FullName'})

# %%
data.head(5)
# Out:
#        ID               Name                      FullName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                         Club     Contract   Positions  ...  \
# 0    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  ...
# 1    92   92             \n\n\n\nJuventus  2018 ~ 2022      ST, LW  ...
# 2    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023          GK  ...
# 3    91   91      \n\n\n\nManchester City  2015 ~ 2023     CAM, CM  ...
# 4    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022     LW, CAM  ...
#
#       A/W     D/W   IR  PAC SHO PAS DRI DEF PHY  Hits
# ...

# %%
data.Joined.head()
# Out:
# 0     Jul 1, 2004
# 1    Jul 10, 2018
# 2    Jul 16, 2014
# 3    Aug 30, 2015
# 4     Aug 3, 2017
# Name: Joined, dtype: object

# %%
data['Joined'] = pd.to_datetime(data['Joined'], format='%b %d, %Y')

data['Joined'] = data['Joined'].dt.strftime('%Y-%m-%d')

# %%
data.Joined.head()
# Out:
# 0    2004-07-01
# 1    2018-07-10
# 2    2014-07-16
# 3    2015-08-30
# 4    2017-08-03
# Name: Joined, dtype: object

# %%
data=data.rename(columns={'↓OVA':'OVA'})

# %%
data['Club']=data['Club'].str.replace('\n\n\n\n','')

# %%
data['on_loan'] = data['Joined'].str.contains('On Loan')

data['free'] = data['Joined'].str.contains('Free')

data['Joined'] = data['Joined'].str.replace('On Loan', '').str.replace('Free', '').str.strip()

data['Status'] = 'active'
data.loc[data['on_loan'], 'Status'] = 'on loan'
data.loc[data['free'], 'Status'] = 'free'

# %%
data.tail(5)
# Out:
#            ID          Name        FullName Nationality  Age  OVA  POT  \
# 18974  247223        Xia Ao          Ao Xia    China PR   21   47   55
# 18975  258760      B. Hough       Ben Hough     England   17   47   67
# 18976  252757   R. McKinley  Ronan McKinley     England   18   47   65
# 18977  243790  Wang Zhen'ao    Zhen'ao Wang    China PR   20   47   57
# 18978  252520     Zhou Xiao       Xiao Zhou    China PR   21   47   57
#
#                    Club     Contract Positions  ... PAC SHO PAS  DRI DEF PHY  \
# 18974        Wuhan Zall  2018 ~ 2022        CB  ...  64  28  26   38  48  51
# 18975   Oldham Athletic  2020 ~ 2021        CM  ...  64  40  48   49  35  45
# 18976        Derry City  2019 ~ 2020        CM  ...  63  39  44   46  40  53
# 18977  Dalian YiFang FC  2020 ~ 2022        RW  ...  58  49  41   49  30  44
# 18978  Dalian YiFang FC  2019 ~ 2023    CB, LB  ...  62  22  39   42  45  55
#
#       Hits on_loan   free  Status
# 18974    0   False  False  active
# ...

# %%
new_order = list(data.columns[:9]) + ['Status'] + list(data.columns[9:])
data = data[new_order]
data.drop(data.iloc[:,-3:],axis=1,inplace=True)
# Out:
# <ipython-input-473-58e3d267bccd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(data.iloc[:,-3:],axis=1,inplace=True)

# %%
data['Contract']=data['Contract'].str.replace('~','-')
# Out:
# <ipython-input-474-2e875a762798>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Contract']=data['Contract'].str.replace('~','-')

# %%
data.tail(5)
# Out:
#            ID          Name        FullName Nationality  Age  OVA  POT  \
# 18974  247223        Xia Ao          Ao Xia    China PR   21   47   55
# 18975  258760      B. Hough       Ben Hough     England   17   47   67
# 18976  252757   R. McKinley  Ronan McKinley     England   18   47   65
# 18977  243790  Wang Zhen'ao    Zhen'ao Wang    China PR   20   47   57
# 18978  252520     Zhou Xiao       Xiao Zhou    China PR   21   47   57
#
#                    Club     Contract Positions  ...     A/W     D/W   IR  PAC  \
# 18974        Wuhan Zall  2018 - 2022        CB  ...  Medium  Medium  1 ★   64
# 18975   Oldham Athletic  2020 - 2021        CM  ...  Medium  Medium  1 ★   64
# 18976        Derry City  2019 - 2020        CM  ...  Medium  Medium  1 ★   63
# 18977  Dalian YiFang FC  2020 - 2022        RW  ...  Medium  Medium  1 ★   58
# 18978  Dalian YiFang FC  2019 - 2023    CB, LB  ...  Medium  Medium  1 ★   62
#
#       SHO PAS DRI DEF PHY  Hits
# 18974  28  26  38  48  51     0
# ...

# %%
def remove_star(x):
    x = x.replace('★', '')
    return x

# %%
data.IR = data.IR.apply(remove_star)
data.SM = data.SM.apply(remove_star)
data['W/F'] = data['W/F'].apply(remove_star)
data.head()
# Out:
# <ipython-input-477-42a87764de6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.IR = data.IR.apply(remove_star)
# <ipython-input-477-42a87764de6f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.SM = data.SM.apply(remove_star)
# <ipython-input-477-42a87764de6f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data.Height.unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
import re

def convert_height_to_cm(height):
    if 'cm' in height:
        cm_value = int(re.search(r'\d+', height).group())
        return cm_value
    else:
        feet, inches = map(int, re.findall(r'\d+', height))
        total_inches = feet * 12 + inches
        total_centimeters = total_inches * 2.54
        return total_centimeters

data['Height'] = data['Height'].apply(convert_height_to_cm)

# %%
data=data.rename(columns={'Height':'Height(cm)' })

# %%
data['Height(cm)'].unique()
# Out:
# array([170.  , 187.  , 188.  , 181.  , 175.  , 184.  , 191.  , 178.  ,
#        193.  , 185.  , 199.  , 173.  , 168.  , 176.  , 177.  , 183.  ,
#        180.  , 189.  , 179.  , 195.  , 172.  , 182.  , 186.  , 192.  ,
#        165.  , 194.  , 167.  , 196.  , 163.  , 190.  , 174.  , 169.  ,
#        171.  , 197.  , 200.  , 166.  , 187.96, 164.  , 198.  , 190.5 ,
#        195.58, 180.34, 193.04, 185.42, 182.88, 177.8 , 175.26, 167.64,
#        170.18, 162.56, 201.  , 158.  , 162.  , 161.  , 160.  , 203.  ,
#        157.  , 156.  , 202.  , 159.  , 206.  , 155.  ])

# %%
data.Weight.unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
def convert_weight_to_kg(weight):
    if 'kg' in weight:
        kg_value = int(re.search(r'\d+', weight).group())
        return kg_value
    elif 'lbs' in weight:
        lbs_value = int(re.search(r'\d+', weight).group())
        kg_value = lbs_value * 0.45359237
        return kg_value

data['Weight'] = data['Weight'].apply(convert_weight_to_kg)
data['Weight'] = data['Weight'].round().astype(int)

# %%
data=data.rename(columns={'Weight':'Weight(Kg)' })

# %%
data['Weight(Kg)'].unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52])

# %%
data["Release Clause"].unique()
# Out:
# array(['€138.4M', '€75.9M', '€159.4M', ..., '€59K', '€35K', '€64K'],
#       dtype=object)

# %%
def convert_to_numeric(converto):
    numeric_value = 0  # Default value

    if isinstance(converto, str):
        if 'M' in converto:
            match = re.search(r'\d+\.\d+', converto)
            numeric_value = float(match.group()) * 1e6 if match else 0
        elif 'K' in converto:
            match = re.search(r'\d+', converto)
            numeric_value = float(match.group()) * 1e3 if match else 0
    elif isinstance(converto, (int, float)):
        numeric_value = float(converto)

    return '{:.0f}'.format(numeric_value)

data["Release Clause"] = data["Release Clause"].apply(convert_to_numeric)

# %%
data=data.rename(columns={"Release Clause":"Release Clause(€)" })

# %%
data["Release Clause(€)"].unique()
# Out:
# array(['138400000', '75900000', '159400000', ..., '59000', '35000',
#        '64000'], dtype=object)

# %%
data['Wage'].unique()
# Out:
# array(['€560K', '€220K', '€125K', '€370K', '€270K', '€240K', '€250K',
#        '€160K', '€260K', '€210K', '€310K', '€130K', '€350K', '€300K',
#        '€190K', '€145K', '€195K', '€100K', '€140K', '€290K', '€82K',
#        '€110K', '€230K', '€155K', '€200K', '€165K', '€95K', '€170K',
#        '€105K', '€115K', '€150K', '€135K', '€55K', '€58K', '€81K', '€34K',
#        '€120K', '€59K', '€90K', '€65K', '€56K', '€71K', '€18K', '€75K',
#        '€47K', '€20K', '€84K', '€86K', '€74K', '€78K', '€27K', '€68K',
#        '€85K', '€25K', '€46K', '€83K', '€54K', '€79K', '€175K', '€43K',
#        '€49K', '€45K', '€38K', '€41K', '€39K', '€23K', '€51K', '€50K',
#        '€87K', '€30K', '€14K', '€69K', '€31K', '€64K', '€53K', '€35K',
#        '€21K', '€28K', '€17K', '€33K', '€70K', '€32K', '€89K', '€26K',
#        '€40K', '€76K', '€72K', '€48K', '€36K', '€29K', '€60K', '€16K',
#        '€37K', '€24K', '€52K', '€0', '€62K', '€73K', '€63K', '€19K',
# ...

# %%
data['Wage']=data['Wage'].apply(convert_to_numeric)

# %%
data=data.rename(columns={"Wage":"Wage(€)" })

# %%
data['Wage(€)'].unique()
# Out:
# array(['560000', '220000', '125000', '370000', '270000', '240000',
#        '250000', '160000', '260000', '210000', '310000', '130000',
#        '350000', '300000', '190000', '145000', '195000', '100000',
#        '140000', '290000', '82000', '110000', '230000', '155000',
#        '200000', '165000', '95000', '170000', '105000', '115000',
#        '150000', '135000', '55000', '58000', '81000', '34000', '120000',
#        '59000', '90000', '65000', '56000', '71000', '18000', '75000',
#        '47000', '20000', '84000', '86000', '74000', '78000', '27000',
#        '68000', '85000', '25000', '46000', '83000', '54000', '79000',
#        '175000', '43000', '49000', '45000', '38000', '41000', '39000',
#        '23000', '51000', '50000', '87000', '30000', '14000', '69000',
#        '31000', '64000', '53000', '35000', '21000', '28000', '17000',
#        '33000', '70000', '32000', '89000', '26000', '40000', '76000',
#        '72000', '48000', '36000', '29000', '60000', '16000', '37000',
# ...

# %%
data.Value.unique()
# Out:
# array(['€103.5M', '€63M', '€120M', '€129M', '€132M', '€111M', '€120.5M',
#        '€102M', '€185.5M', '€110M', '€113M', '€90.5M', '€82M', '€17.5M',
#        '€83.5M', '€33.5M', '€114.5M', '€78M', '€103M', '€109M', '€92M',
#        '€10M', '€76.5M', '€89.5M', '€87.5M', '€79.5M', '€124M', '€114M',
#        '€95M', '€92.5M', '€105.5M', '€88.5M', '€85M', '€81.5M', '€26M',
#        '€21M', '€56M', '€67.5M', '€53M', '€36.5M', '€51M', '€65.5M',
#        '€46.5M', '€61.5M', '€72.5M', '€77.5M', '€43.5M', '€32.5M', '€36M',
#        '€32M', '€54M', '€49.5M', '€57M', '€66.5M', '€74.5M', '€71.5M',
#        '€121M', '€99M', '€67M', '€86.5M', '€93.5M', '€70M', '€62M',
#        '€66M', '€58M', '€44M', '€81M', '€37M', '€14.5M', '€46M', '€47.5M',
#        '€52.5M', '€54.5M', '€34.5M', '€57.5M', '€51.5M', '€44.5M', '€55M',
#        '€48M', '€60.5M', '€63.5M', '€61M', '€29M', '€58.5M', '€55.5M',
#        '€42M', '€40.5M', '€43M', '€45.5M', '€34M', '€26.5M', '€42.5M',
# ...

# %%
data['Value']=data['Value'].apply(convert_to_numeric)

# %%
data=data.rename(columns={"Value":"Value(€)" })

# %%
data["Value(€)"].unique()
# Out:
# array(['103500000', '0', '120500000', '185500000', '90500000', '17500000',
#        '83500000', '33500000', '114500000', '76500000', '89500000',
#        '87500000', '79500000', '92500000', '105500000', '88500000',
#        '81500000', '67500000', '36500000', '65500000', '46500000',
#        '61500000', '72500000', '77500000', '43500000', '32500000',
#        '49500000', '66500000', '74500000', '71500000', '86500000',
#        '93500000', '14500000', '47500000', '52500000', '54500000',
#        '34500000', '57500000', '51500000', '44500000', '60500000',
#        '63500000', '58500000', '55500000', '40500000', '45500000',
#        '26500000', '42500000', '35500000', '41500000', '13500000',
#        '29500000', '15500000', '38500000', '73500000', '30500000',
#        '25500000', '23500000', '31500000', '22500000', '28500000',
#        '12500000', '37500000', '27500000', '20500000', '3400000',
#        '56500000', '62500000', '24500000', '21500000', '8500000',
# ...

# %%
data.Hits.unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %%
data['Hits']=data['Hits'].apply(convert_to_numeric)

# %%
data.Hits.unique()
# Out:
# array(['0', '1000', '3000', '2000', '8000', '4000', '6000', '11', '2',
#        '1', '31', '3', '10', '9', '17', '7', '4', '6'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 74 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 18979 non-null  int64
#  1   Name               18979 non-null  object
#  2   FullName           18979 non-null  object
#  3   Nationality        18979 non-null  object
#  4   Age                18979 non-null  int64
#  5   OVA                18979 non-null  int64
#  6   POT                18979 non-null  int64
#  7   Club               18979 non-null  object
#  8   Contract           18979 non-null  object
#  9   Positions          18979 non-null  object
#  10  Height(cm)         18979 non-null  float64
#  11  Weight(Kg)         18979 non-null  int64
#  12  Preferred Foot     18979 non-null  object
#  13  BOV                18979 non-null  int64
#  14  Best Position      18979 non-null  object
#  15  Joined             18979 non-null  object
# ...

# %%
data_types = {
    'Value(€)': 'int64',
    'Wage(€)': 'int64',
    'Release Clause(€)': 'int64',
    'Hits': 'int64',
    'W/F': 'int64',
    'SM': 'int64',
    'IR': 'int64'
}

data = data.astype(data_types)

# %%
data.Positions.unique()
# Out:
# array(['RW, ST, CF', 'ST, LW', 'GK', 'CAM, CM', 'LW, CAM', 'ST', 'RW',
#        'ST, LW, RW', 'CB', 'LW', 'CDM', 'CF, ST', 'LW, RW', 'CDM, CM',
#        'CDM, RB', 'CF, CAM', 'LW, ST', 'CM', 'ST, CF, LW', 'RM, LM, CAM',
#        'RB', 'RW, CAM, CM', 'LB', 'LM, CF', 'CF', 'RW, LW', 'CAM, RM, RW',
#        'CM, CDM', 'CAM, CF, ST', 'CM, CDM, CAM', 'CF, LW, CAM',
#        'CAM, RM, CF', 'LM, ST', 'RM, LM, RW', 'LM', 'CAM, RW', 'CB, CDM',
#        'RW, RM', 'LW, CF', 'CM, RM, LM', 'LB, LM', 'CAM, CM, RM',
#        'CAM, CM, CF', 'CAM, CF', 'LM, RM, LW', 'LM, LB, CM', 'CM, LM, LB',
#        'RM, RW', 'RM, CM', 'CAM, CM, LW', 'CB, LB', 'RM, RB', 'ST, RW',
#        'LM, RW, LW', 'RB, LB', 'RB, RM', 'RM', 'LM, RM, CF', 'CAM, RM',
#        'RB, RWB', 'CDM, CB, CM', 'CAM, RM, ST', 'LM, LW, RM', 'CM, CAM',
#        'ST, RM, CF', 'LM, RM', 'RM, CF', 'LM, LWB', 'RW, RM, CF',
#        'RB, CM', 'LW, CAM, RW', 'CAM, LW, CM', 'CM, CAM, CDM',
# ...

# %%
data.Positions.nunique()
# Out:
# 640

# %%
def sort_row(row):
    return ', '.join(sorted(row.split(', ')))

data['Positions'] = data['Positions'].apply(sort_row)

# %%
data.Positions.unique()
# Out:
# array(['CF, RW, ST', 'LW, ST', 'GK', 'CAM, CM', 'CAM, LW', 'ST', 'RW',
#        'LW, RW, ST', 'CB', 'LW', 'CDM', 'CF, ST', 'LW, RW', 'CDM, CM',
#        'CDM, RB', 'CAM, CF', 'CM', 'CF, LW, ST', 'CAM, LM, RM', 'RB',
#        'CAM, CM, RW', 'LB', 'CF, LM', 'CF', 'CAM, RM, RW', 'CAM, CF, ST',
#        'CAM, CDM, CM', 'CAM, CF, LW', 'CAM, CF, RM', 'LM, ST',
#        'LM, RM, RW', 'LM', 'CAM, RW', 'CB, CDM', 'RM, RW', 'CF, LW',
#        'CM, LM, RM', 'LB, LM', 'CAM, CM, RM', 'CAM, CF, CM', 'LM, LW, RM',
#        'CM, LB, LM', 'CM, RM', 'CAM, CM, LW', 'CB, LB', 'RB, RM',
#        'RW, ST', 'LM, LW, RW', 'LB, RB', 'RM', 'CF, LM, RM', 'CAM, RM',
#        'RB, RWB', 'CB, CDM, CM', 'CAM, RM, ST', 'CF, RM, ST', 'LM, RM',
#        'CF, RM', 'LM, LWB', 'CF, RM, RW', 'CM, RB', 'CAM, LW, RW',
#        'CAM, CM, LM', 'CM, RM, ST', 'CDM, CM, RB', 'CAM, ST',
#        'CAM, LW, ST', 'CB, LB, LWB', 'RM, ST', 'CB, CDM, LB', 'RM, RWB',
# ...

# %%
data.Positions.nunique()
# Out:
# 238

# %%
data.to_csv('cleaned fifa21.csv')
